# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik5412/News-Classifier/blob/master/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importing libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import nltk as nl
import matplotlib.pyplot as plt
import seaborn

# %%
bussiness = pd.read_csv('/content/drive/MyDrive/news classifier/Datasets/business_data.csv')

education = pd.read_csv('/content/drive/MyDrive/news classifier/Datasets/education_data.csv')

entertainment = pd.read_csv('/content/drive/MyDrive/news classifier/Datasets/entertainment_data.csv')

sports = pd.read_csv('/content/drive/MyDrive/news classifier/Datasets/sports_data.csv')

technology = pd.read_csv('/content/drive/MyDrive/news classifier/Datasets/technology_data.csv')

# %%
import sklearn
print(f"Colab scikit-learn version: {sklearn.__version__}")
# Out:
# Colab scikit-learn version: 1.8.0

# %%
# !pip install --upgrade scikit-learn==1.8.0

# %%
df = pd.concat([bussiness, education, entertainment, sports, technology], axis= 0)

df = df.sample(frac= 1).reset_index(drop= True)

df
# Out:
#                                               headlines  \
# 0     In FSSAI index, nearly all major states slip o...
# 1     5 launchers for UI customisations to make the ...
# 2     She dabbled in karting and badminton. Now, Esh...
# 3     AP ECET 2023 Counselling: Phase 1 registration...
# 4     My dear students | The movie Air and its take ...
# ...                                                 ...
# 9995  BITS Pilani VC Ramgopal Rao gets VLSI Lifetime...
# 9996  JEE, NEET 2024: Entrance exam for Bihar board’...
# 9997  Ravindra Jadeja has a better batting average t...
# 9998  Naga Chaitanya on streaming debut with Dhootha...
# 9999        Check fellowships for writing science books
#
#                                             description  \
# 0     After adjusting for a new parameter included i...
# 1     These five launchers can fully transform the l...
# 2     Daughter of a rally driver, 19-year-old wins I...
# 3     Candidates can apply for the counselling by vi...
# ...

# %%
df['category'].value_counts()
# Out:
# category
# business         2000
# technology       2000
# sports           2000
# education        2000
# entertainment    2000
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# headlines      0
# description    0
# content        0
# url            0
# category       0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 5)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (10000, 5)

# %%
df
# Out:
#                                               headlines  \
# 0     In FSSAI index, nearly all major states slip o...
# 1     5 launchers for UI customisations to make the ...
# 2     She dabbled in karting and badminton. Now, Esh...
# 3     AP ECET 2023 Counselling: Phase 1 registration...
# 4     My dear students | The movie Air and its take ...
# ...                                                 ...
# 9995  BITS Pilani VC Ramgopal Rao gets VLSI Lifetime...
# 9996  JEE, NEET 2024: Entrance exam for Bihar board’...
# 9997  Ravindra Jadeja has a better batting average t...
# 9998  Naga Chaitanya on streaming debut with Dhootha...
# 9999        Check fellowships for writing science books
#
#                                             description  \
# 0     After adjusting for a new parameter included i...
# 1     These five launchers can fully transform the l...
# 2     Daughter of a rally driver, 19-year-old wins I...
# 3     Candidates can apply for the counselling by vi...
# ...

# %%
# Dropping unwanted columns for this

df = df.drop(columns= ['url'])
df_copy = df.copy()
df
# Out:
#                                               headlines  \
# 0     In FSSAI index, nearly all major states slip o...
# 1     5 launchers for UI customisations to make the ...
# 2     She dabbled in karting and badminton. Now, Esh...
# 3     AP ECET 2023 Counselling: Phase 1 registration...
# 4     My dear students | The movie Air and its take ...
# ...                                                 ...
# 9995  BITS Pilani VC Ramgopal Rao gets VLSI Lifetime...
# 9996  JEE, NEET 2024: Entrance exam for Bihar board’...
# 9997  Ravindra Jadeja has a better batting average t...
# 9998  Naga Chaitanya on streaming debut with Dhootha...
# 9999        Check fellowships for writing science books
#
#                                             description  \
# 0     After adjusting for a new parameter included i...
# 1     These five launchers can fully transform the l...
# 2     Daughter of a rally driver, 19-year-old wins I...
# 3     Candidates can apply for the counselling by vi...
# ...

# %% [markdown]
# ### Making Pipeline

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import re
import string

class processing(BaseEstimator,TransformerMixin) :
    def fit(self, x, y=None ) :
        return self

    def healper(self, x):
        x = re.sub(r'[^a-zA-z\s]','',x.lower())
        return ' '.join(x.split())

    def transform(self, x) :
        combined = (x['headlines'].astype(str) + ' ' +
                    x['description'].astype(str) + ' ' +
                    x['content'].astype(str))

        return combined.apply(self.healper).tolist()

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

text_pipe = Pipeline([
    ('Text',processing()),
    ('Vectorizer', TfidfVectorizer(stop_words='english'))
])

prep_pipe = ColumnTransformer([
    ('Processing', text_pipe,['headlines', 'description', 'content'])
], remainder= 'passthrough')

pipe = Pipeline([
    ('preprocessing', prep_pipe),
    ('Classifier', LogisticRegression(max_iter= 1000, class_weight= 'balanced'))
])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['enc'] = le.fit_transform(df['category'])

# %%
df['enc'].value_counts()
# Out:
# enc
# 0    2000
# 4    2000
# 3    2000
# 1    2000
# 2    2000
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df.drop(columns=['category', 'enc']), df['enc'], test_size= 0.33, random_state= 42)

# %%
x_train
# Out:
#                                               headlines  \
# 8371     Angel One slips 7% after NSE imposes penalties
# 5027  Imran Khan dances on ‘Pappu Can’t Dance’, Ira ...
# 9234  Karnataka forms new textbook revision panel, g...
# 3944  Chandrayaan-3 lander establishes communication...
# 6862  No written communication from I-T Dept on sear...
# ...                                                 ...
# 5734  FPIs sell 35,000 crore in domestic shares over...
# 5191  Telangana TOSS SSC, Intermediate October 2023 ...
# 5390  Bill on data protection gets Cabinet approval,...
# 860   Time for Ishan, Hooda to fire as captain Pandy...
# 7270  Vedang Raina denies rumours of dating Khushi K...
#
#                                             description  \
# 8371  Netweb Technologies' IPO aims to raise 631 cro...
# 5027  Imran Khan enjoyed cousin Ira Khan's wedding c...
# 9234  The primary mandate of the 37-member committee...
# 3944  The orbiter had played a role in identifying a...
# ...

# %%
pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Processing',
#                                                   Pipeline(steps=[('Text',
#                                                                    processing()),
#                                                                   ('Vectorizer',
#                                                                    TfidfVectorizer(stop_words='english'))]),
#                                                   ['headlines', 'description',
#                                                    'content'])])),
#                 ('Classifier',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
pred = pipe.predict(x_test)

# %%
y_test
# Out:
# 6252    4
# 4684    2
# 1731    2
# 4742    3
# 4521    2
#        ..
# 1744    2
# 9754    2
# 6094    1
# 8781    1
# 9401    1
# Name: enc, Length: 3300, dtype: int64

# %%
pred
# Out:
# array([4, 2, 2, ..., 1, 1, 1])

# %%
from sklearn.metrics import accuracy_score, classification_report

acc = accuracy_score(y_true= y_test, y_pred= pred)

acc
# Out:
# 0.9854545454545455

# %%
pipe.score(x_train, y_train)
# Out:
# 0.9944776119402985

# %%
pipe.score(x_test, y_test)
# Out:
# 0.9854545454545455

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       654
#            1       1.00      1.00      1.00       650
#            2       1.00      1.00      1.00       650
#            3       0.99      0.99      0.99       675
#            4       0.97      0.97      0.97       671
#
#     accuracy                           0.99      3300
#    macro avg       0.99      0.99      0.99      3300
# weighted avg       0.99      0.99      0.99      3300

# %%
import joblib

joblib.dump(pipe, 'Pipeline_new.plk')
joblib.dump(le, 'Label_encoder.plk')
# Out:
# ['Label_encoder.plk']
