# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import nltk as nl
import matplotlib.pyplot as plt
import seaborn

# %%
df = pd.read_json('News_Category_Dataset_v3.json', lines= True)
df
# Out:
#                                                      link  \
# 0       https://www.huffpost.com/entry/covid-boosters-...
# 1       https://www.huffpost.com/entry/american-airlin...
# 2       https://www.huffpost.com/entry/funniest-tweets...
# 3       https://www.huffpost.com/entry/funniest-parent...
# 4       https://www.huffpost.com/entry/amy-cooper-lose...
# ...                                                   ...
# 209522  https://www.huffingtonpost.com/entry/rim-ceo-t...
# 209523  https://www.huffingtonpost.com/entry/maria-sha...
# 209524  https://www.huffingtonpost.com/entry/super-bow...
# 209525  https://www.huffingtonpost.com/entry/aldon-smi...
# 209526  https://www.huffingtonpost.com/entry/dwight-ho...
#
#                                                  headline   category  \
# 0       Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1       American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2       23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3       The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4       Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
# ...                                                   ...        ...
# 209522  RIM CEO Thorsten Heins' 'Significant' Plans Fo...       TECH
# 209523  Maria Sharapova Stunned By Victoria Azarenka I...     SPORTS
# 209524  Giants Over Patriots, Jets Over Colts Among  M...     SPORTS
# 209525  Aldon Smith Arrested: 49ers Linebacker Busted ...     SPORTS
# 209526  Dwight Howard Rips Teammates After Magic Loss ...     SPORTS
#
#                                         short_description  \
# 0       Health experts said it is too early to predict...
# 1       He was subdued by passengers and crew when he ...
# 2       "Until you have a dog you don't understand wha...
# 3       "Accidentally put grown-up toothpaste on my to...
# 4       Amy Cooper accused investment firm Franklin Te...
# ...                                                   ...
# 209522  Verizon Wireless and AT&T are already promotin...
# 209523  Afterward, Azarenka, more effusive with the pr...
# 209524  Leading up to Super Bowl XLVI, the most talked...
# 209525  CORRECTION: An earlier version of this story i...
# 209526  The five-time all-star center tore into his te...
#
#                      authors       date
# 0       Carla K. Johnson, AP 2022-09-23
# 1             Mary Papenfuss 2022-09-23
# 2              Elyse Wanshel 2022-09-23
# 3           Caroline Bologna 2022-09-23
# 4             Nina Golgowski 2022-09-22
# ...                      ...        ...
# 209522      Reuters, Reuters 2012-01-28
# 209523                       2012-01-28
# 209524                       2012-01-28
# 209525                       2012-01-28
# 209526                       2012-01-28
#
# [209527 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# link                 0
# headline             0
# category             0
# short_description    0
# authors              0
# date                 0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                                                      link  \
# 0       https://www.huffpost.com/entry/covid-boosters-...
# 1       https://www.huffpost.com/entry/american-airlin...
# 2       https://www.huffpost.com/entry/funniest-tweets...
# 3       https://www.huffpost.com/entry/funniest-parent...
# 4       https://www.huffpost.com/entry/amy-cooper-lose...
# ...                                                   ...
# 209522  https://www.huffingtonpost.com/entry/rim-ceo-t...
# 209523  https://www.huffingtonpost.com/entry/maria-sha...
# 209524  https://www.huffingtonpost.com/entry/super-bow...
# 209525  https://www.huffingtonpost.com/entry/aldon-smi...
# 209526  https://www.huffingtonpost.com/entry/dwight-ho...
#
#                                                  headline   category  \
# 0       Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1       American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2       23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3       The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4       Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
# ...                                                   ...        ...
# 209522  RIM CEO Thorsten Heins' 'Significant' Plans Fo...       TECH
# 209523  Maria Sharapova Stunned By Victoria Azarenka I...     SPORTS
# 209524  Giants Over Patriots, Jets Over Colts Among  M...     SPORTS
# 209525  Aldon Smith Arrested: 49ers Linebacker Busted ...     SPORTS
# 209526  Dwight Howard Rips Teammates After Magic Loss ...     SPORTS
#
#                                         short_description  \
# 0       Health experts said it is too early to predict...
# 1       He was subdued by passengers and crew when he ...
# 2       "Until you have a dog you don't understand wha...
# 3       "Accidentally put grown-up toothpaste on my to...
# 4       Amy Cooper accused investment firm Franklin Te...
# ...                                                   ...
# 209522  Verizon Wireless and AT&T are already promotin...
# 209523  Afterward, Azarenka, more effusive with the pr...
# 209524  Leading up to Super Bowl XLVI, the most talked...
# 209525  CORRECTION: An earlier version of this story i...
# 209526  The five-time all-star center tore into his te...
#
#                      authors       date
# 0       Carla K. Johnson, AP 2022-09-23
# 1             Mary Papenfuss 2022-09-23
# 2              Elyse Wanshel 2022-09-23
# 3           Caroline Bologna 2022-09-23
# 4             Nina Golgowski 2022-09-22
# ...                      ...        ...
# 209522      Reuters, Reuters 2012-01-28
# 209523                       2012-01-28
# 209524                       2012-01-28
# 209525                       2012-01-28
# 209526                       2012-01-28
#
# [209514 rows x 6 columns]

# %%
# Dropping unwanted columns for this

df = df.drop(columns= ['link','authors'])
df_copy = df.copy()
df
# Out:
#                                                  headline   category  \
# 0       Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1       American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2       23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3       The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4       Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
# ...                                                   ...        ...
# 209522  RIM CEO Thorsten Heins' 'Significant' Plans Fo...       TECH
# 209523  Maria Sharapova Stunned By Victoria Azarenka I...     SPORTS
# 209524  Giants Over Patriots, Jets Over Colts Among  M...     SPORTS
# 209525  Aldon Smith Arrested: 49ers Linebacker Busted ...     SPORTS
# 209526  Dwight Howard Rips Teammates After Magic Loss ...     SPORTS
#
#                                         short_description       date
# 0       Health experts said it is too early to predict... 2022-09-23
# 1       He was subdued by passengers and crew when he ... 2022-09-23
# 2       "Until you have a dog you don't understand wha... 2022-09-23
# 3       "Accidentally put grown-up toothpaste on my to... 2022-09-23
# 4       Amy Cooper accused investment firm Franklin Te... 2022-09-22
# ...                                                   ...        ...
# 209522  Verizon Wireless and AT&T are already promotin... 2012-01-28
# 209523  Afterward, Azarenka, more effusive with the pr... 2012-01-28
# 209524  Leading up to Super Bowl XLVI, the most talked... 2012-01-28
# 209525  CORRECTION: An earlier version of this story i... 2012-01-28
# 209526  The five-time all-star center tore into his te... 2012-01-28
#
# [209514 rows x 4 columns]

# %%
from tfr import processing_text, processing_date

prep = processing_text()
dot = processing_date()

df[['headline', 'category', 'short_description']] = prep.fit_transform(df[['headline', 'category', 'short_description']])

df
# Out:
#                                                  headline   category  \
# 0       over  million americans roll up sleeves for om...    us news
# 1       american airlines flyer charged banned for lif...    us news
# 2        of the funniest tweets about cats and dogs th...     comedy
# 3        the funniest tweets from parents this week sept   parenting
# 4       woman who called cops on black birdwatcher los...    us news
# ...                                                   ...        ...
# 209522  rim ceo thorsten heins significant plans for b...       tech
# 209523  maria sharapova stunned by victoria azarenka i...     sports
# 209524  giants over patriots jets over colts among  mo...     sports
# 209525  aldon smith arrested ers linebacker busted for...     sports
# 209526  dwight howard rips teammates after magic loss ...     sports
#
#                                         short_description       date
# 0       health experts said it is too early to predict... 2022-09-23
# 1       he was subdued by passengers and crew when he ... 2022-09-23
# 2       until you have a dog you dont understand what ... 2022-09-23
# 3       accidentally put grownup toothpaste on my todd... 2022-09-23
# 4       amy cooper accused investment firm franklin te... 2022-09-22
# ...                                                   ...        ...
# 209522  verizon wireless and att are already promoting... 2012-01-28
# 209523  afterward azarenka more effusive with the pres... 2012-01-28
# 209524  leading up to super bowl xlvi the most talked ... 2012-01-28
# 209525  correction an earlier version of this story in... 2012-01-28
# 209526  the fivetime allstar center tore into his team... 2012-01-28
#
# [209514 rows x 4 columns]

# %%
dot.fit_transform(df)
# Out:
#                                                  headline   category  \
# 0       over  million americans roll up sleeves for om...    us news
# 1       american airlines flyer charged banned for lif...    us news
# 2        of the funniest tweets about cats and dogs th...     comedy
# 3        the funniest tweets from parents this week sept   parenting
# 4       woman who called cops on black birdwatcher los...    us news
# ...                                                   ...        ...
# 209522  rim ceo thorsten heins significant plans for b...       tech
# 209523  maria sharapova stunned by victoria azarenka i...     sports
# 209524  giants over patriots jets over colts among  mo...     sports
# 209525  aldon smith arrested ers linebacker busted for...     sports
# 209526  dwight howard rips teammates after magic loss ...     sports
#
#                                         short_description  year  day_sine  \
# 0       health experts said it is too early to predict...  2022 -0.032252
# 1       he was subdued by passengers and crew when he ...  2022 -0.032252
# 2       until you have a dog you dont understand what ...  2022 -0.032252
# 3       accidentally put grownup toothpaste on my todd...  2022 -0.032252
# 4       amy cooper accused investment firm franklin te...  2022 -0.032252
# ...                                                   ...   ...       ...
# 209522  verizon wireless and att are already promoting...  2012 -0.032252
# 209523  afterward azarenka more effusive with the pres...  2012 -0.032252
# 209524  leading up to super bowl xlvi the most talked ...  2012 -0.032252
# 209525  correction an earlier version of this story in...  2012 -0.032252
# 209526  the fivetime allstar center tore into his team...  2012 -0.032252
#
#         day_cos  month_sine  month_cos  weekday_sine  weekday_cos
# 0       0.99948   -0.083237    0.99653     -0.142372     0.989813
# 1       0.99948   -0.083237    0.99653     -0.142372     0.989813
# 2       0.99948   -0.083237    0.99653     -0.142372     0.989813
# 3       0.99948   -0.083237    0.99653     -0.142372     0.989813
# 4       0.99948   -0.083237    0.99653     -0.142372     0.989813
# ...         ...         ...        ...           ...          ...
# 209522  0.99948   -0.083237    0.99653     -0.142372     0.989813
# 209523  0.99948   -0.083237    0.99653     -0.142372     0.989813
# 209524  0.99948   -0.083237    0.99653     -0.142372     0.989813
# 209525  0.99948   -0.083237    0.99653     -0.142372     0.989813
# 209526  0.99948   -0.083237    0.99653     -0.142372     0.989813
#
# [209514 rows x 10 columns]

# %%
df
# Out:
#                                                  headline   category  \
# 0       over  million americans roll up sleeves for om...    us news
# 1       american airlines flyer charged banned for lif...    us news
# 2        of the funniest tweets about cats and dogs th...     comedy
# 3        the funniest tweets from parents this week sept   parenting
# 4       woman who called cops on black birdwatcher los...    us news
# ...                                                   ...        ...
# 209522  rim ceo thorsten heins significant plans for b...       tech
# 209523  maria sharapova stunned by victoria azarenka i...     sports
# 209524  giants over patriots jets over colts among  mo...     sports
# 209525  aldon smith arrested ers linebacker busted for...     sports
# 209526  dwight howard rips teammates after magic loss ...     sports
#
#                                         short_description       date  weekday  \
# 0       health experts said it is too early to predict... 2022-09-23        4
# 1       he was subdued by passengers and crew when he ... 2022-09-23        4
# 2       until you have a dog you dont understand what ... 2022-09-23        4
# 3       accidentally put grownup toothpaste on my todd... 2022-09-23        4
# 4       amy cooper accused investment firm franklin te... 2022-09-22        3
# ...                                                   ...        ...      ...
# 209522  verizon wireless and att are already promoting... 2012-01-28        5
# 209523  afterward azarenka more effusive with the pres... 2012-01-28        5
# 209524  leading up to super bowl xlvi the most talked ... 2012-01-28        5
# 209525  correction an earlier version of this story in... 2012-01-28        5
# 209526  the fivetime allstar center tore into his team... 2012-01-28        5
#
#         day  month  year  day_sine  day_cos  month_sine  month_cos  \
# 0        23      9  2022 -0.032252  0.99948   -0.083237    0.99653
# 1        23      9  2022 -0.032252  0.99948   -0.083237    0.99653
# 2        23      9  2022 -0.032252  0.99948   -0.083237    0.99653
# 3        23      9  2022 -0.032252  0.99948   -0.083237    0.99653
# 4        22      9  2022 -0.032252  0.99948   -0.083237    0.99653
# ...     ...    ...   ...       ...      ...         ...        ...
# 209522   28      1  2012 -0.032252  0.99948   -0.083237    0.99653
# 209523   28      1  2012 -0.032252  0.99948   -0.083237    0.99653
# 209524   28      1  2012 -0.032252  0.99948   -0.083237    0.99653
# 209525   28      1  2012 -0.032252  0.99948   -0.083237    0.99653
# 209526   28      1  2012 -0.032252  0.99948   -0.083237    0.99653
#
#         weekday_sine  weekday_cos
# 0          -0.142372     0.989813
# 1          -0.142372     0.989813
# 2          -0.142372     0.989813
# 3          -0.142372     0.989813
# 4          -0.142372     0.989813
# ...              ...          ...
# 209522     -0.142372     0.989813
# 209523     -0.142372     0.989813
# 209524     -0.142372     0.989813
# 209525     -0.142372     0.989813
# 209526     -0.142372     0.989813
#
# [209514 rows x 14 columns]

# %% [markdown]
# ### Making Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

prep_pipe = ColumnTransformer([
    ('Text Processing', processing_text(),['headline', 'short_description']),
    ('Date Processing', processing_date(),['date']),
], remainder= 'passthrough')

pipe = Pipeline([
    ('preprocessing', prep_pipe)
])
pipe.fit_transform(df_copy.drop(columns='category'))
# Out:
# array([['over  million americans roll up sleeves for omicrontargeted covid boosters',
#         'health experts said it is too early to predict whether demand would match up with the  million doses of the new boosters the us ordered for the fall',
#         2022.0, ..., 0.996529786700559, -0.14237172979226415,
#         0.989813260446615],
#        ['american airlines flyer charged banned for life after punching flight attendant on video',
#         'he was subdued by passengers and crew when he fled to the back of the aircraft after the confrontation according to the us attorneys office in los angeles',
#         2022.0, ..., 0.996529786700559, -0.14237172979226415,
#         0.989813260446615],
#        [' of the funniest tweets about cats and dogs this week sept ',
#         'until you have a dog you dont understand what could be eaten',
#         2022.0, ..., 0.996529786700559, -0.14237172979226415,
#         0.989813260446615],
#        ...,
#        ['giants over patriots jets over colts among  most improbable super bowl upsets of all time videos',
#         'leading up to super bowl xlvi the most talked about game could end up being one that occurred a few years ago after all',
#         2012.0, ..., 0.9965297867005595, -0.14237172979226437,
#         0.989813260446615],
#        ['aldon smith arrested ers linebacker busted for dui',
#         'correction an earlier version of this story incorrectly stated the location of ktvu and the  league leader in sacks',
#         2012.0, ..., 0.9965297867005595, -0.14237172979226437,
#         0.989813260446615],
#        ['dwight howard rips teammates after magic loss to hornets',
#         'the fivetime allstar center tore into his teammates friday night after orlando committed  turnovers en route to losing',
#         2012.0, ..., 0.9965297867005595, -0.14237172979226437,
#         0.989813260446615]], shape=(209514, 9), dtype=object)

# %%
text_pipe = Pipeline([
    ('Text', processing_text()),
    ('Vec', TfidfVectorizer(stop_words= 'english', lowercase= True))
])

prep_pipe = ColumnTransformer([
    ('Text Processing', text_pipe,['headline', 'short_description']),
    ('Date Processing', processing_date(),['date']),
], remainder= 'passthrough')

pipe = Pipeline([
    ('preprocessing', prep_pipe)
])
pipe.fit_transform(df_copy.drop(columns='category'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 14
#       6 prep_pipe = ColumnTransformer([
#       7     ('Text Processing', text_pipe,['headline', 'short_description']),
#       8     ('Date Processing', processing_date(),['date']),
#       9 ], remainder= 'passthrough')
#      11 pipe = Pipeline([
#      12     ('preprocessing', prep_pipe)
#      13 ])
# ---> 14 pipe.fit_transform(df_copy.drop(columns='category'))
#
# File d:\nlp models\news_clf\env\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File d:\nlp models\news_clf\env\Lib\site-packages\sklearn\pipeline.py:689, in Pipeline.fit_transform(self, X, y, **params)
#     683 last_step_params = self._get_metadata_for_step(
#     684     step_idx=len(self) - 1,
#     685     step_params=routed_params[self.steps[-1][0]],
#     686     all_params=params,
#     687 )
#     688 if hasattr(last_step, "fit_transform"):
# --> 689     return last_step.fit_transform(
#     690         Xt, y, **last_step_params["fit_transform"]
#     691     )
#     692 else:
#     693     return last_step.fit(Xt, y, **last_step_params["fit"]).transform(
#     694         Xt, **last_step_params["transform"]
#     695     )
#
# File d:\nlp models\news_clf\env\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File d:\nlp models\news_clf\env\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File d:\nlp models\news_clf\env\Lib\site-packages\sklearn\compose\_column_transformer.py:1029, in ColumnTransformer.fit_transform(self, X, y, **params)
#    1026 self._validate_output(Xs)
#    1027 self._record_output_indices(Xs)
# -> 1029 return self._hstack(list(Xs), n_samples=n_samples)
#
# File d:\nlp models\news_clf\env\Lib\site-packages\sklearn\compose\_column_transformer.py:1223, in ColumnTransformer._hstack(self, Xs, n_samples)
#    1213         raise ValueError(
#    1214             "Concatenating DataFrames from the transformer's output lead to"
#    1215             " an inconsistent number of samples. The output may have Pandas"
#    (...)   1218             " samples."
#    1219         )
#    1221     return output
# -> 1223 return np.hstack(Xs)
#
# File d:\nlp models\news_clf\env\Lib\site-packages\numpy\_core\shape_base.py:365, in hstack(tup, dtype, casting)
#     363     return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#     364 else:
# --> 365     return _nx.concatenate(arrs, 1, dtype=dtype, casting=casting)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 2 and the array at index 1 has size 209514

# %%
TfidfVectorizer(stop_words='english').fit_transform(processing_text().fit_transform(df[['headline', 'short_description']])['headline'])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1307300 stored elements and shape (209514, 66531)>
