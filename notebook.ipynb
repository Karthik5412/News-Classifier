# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik5412/News-Classifier/blob/master/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importing libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import nltk as nl
import matplotlib.pyplot as plt
import seaborn

# %%
bussiness = pd.read_csv('/content/drive/MyDrive/news classifier/Datasets/business_data.csv')

education = pd.read_csv('/content/drive/MyDrive/news classifier/Datasets/education_data.csv')

entertainment = pd.read_csv('/content/drive/MyDrive/news classifier/Datasets/entertainment_data.csv')

sports = pd.read_csv('/content/drive/MyDrive/news classifier/Datasets/sports_data.csv')

technology = pd.read_csv('/content/drive/MyDrive/news classifier/Datasets/technology_data.csv')

# %%
df = pd.concat([bussiness, education, entertainment, sports, technology], axis= 0)

df = df.sample(frac= 1).reset_index(drop= True)

df
# Out:
#                                               headlines  \
# 0     Alia Bhatt cheers for husband Ranbir Kapoor af...
# 1     UGC removes Meghalaya’s Techno Global Universi...
# 2     Redmi 13C 5G review: Recycling the affordable ...
# 3     Shoaib Akhtar sees Shadab Khan as the next Pak...
# 4          SEBI increases accountability of MF trustees
# ...                                                 ...
# 9995  Ranbir Kapoor’s Animal gets adults only certif...
# 9996  Google year in search 2023: Kiara Advani most ...
# 9997  Luxurious Living Redefined: Mеrlin Group annou...
# 9998  Rajkumar Hirani reveals why he didn’t want to ...
# 9999  Katrina Kaif reveals how ‘green flag’ husband ...
#
#                                             description  \
# 0     The trailer of Ranbir Kapoor's upcoming film A...
# 1     The Techno Global University, Shillong Polytec...
# 2     At Rs 10,999, the phone costs dangerously clos...
# 3     The former Pakistan pacer had criticised Babar...
# 4     While refusing to extend the time, the Delhi H...
# ...                                                 ...
# 9995  Animal marks the first collaboration between R...
# 9996  Kiara Advani and Sidharth Malhotra landed in m...
# 9997  Nestled in the heart of thе vibrant Banеr neig...
# 9998  Did you know that the role of Sukhi in Dunki l...
# 9999  Katrina Kaif and Vicky Kaushal sometimes have ...
#
#                                                 content  \
# 0     Actor Alia Bhatt is highly impressed by the tr...
# 1     The Techno Global University, Shillong Polytec...
# 2     The budget smartphone market in India is heati...
# 3     While former Pakistani speedster Shoaib Akhtar...
# 4     In a setback for low-cost airline, SpiceJet, t...
# ...                                                 ...
# 9995  The Animal is coming. Ranbir Kapoor’s latest a...
# 9996  Google year in search 2023: Kiara Advani tops ...
# 9997  Following the resounding success of its luxuri...
# 9998  Amid the mixed response that his latest film, ...
# 9999  Actor couple Katrina Kaif and Vicky Kaushal ha...
#
#                                                     url       category
# 0     https://indianexpress.com/article/entertainmen...  entertainment
# 1     https://indianexpress.com/article/education/ug...      education
# 2     https://indianexpress.com/article/technology/t...     technology
# 3     https://indianexpress.com/article/sports/crick...         sports
# 4     https://indianexpress.com/article/business/avi...       business
# ...                                                 ...            ...
# 9995  https://indianexpress.com/article/entertainmen...  entertainment
# 9996  https://indianexpress.com/article/entertainmen...  entertainment
# 9997  https://indianexpress.com/article/business/spo...       business
# 9998  https://indianexpress.com/article/entertainmen...  entertainment
# 9999  https://indianexpress.com/article/entertainmen...  entertainment
#
# [10000 rows x 5 columns]

# %%
df['category'].value_counts()
# Out:
# category
# entertainment    2000
# education        2000
# technology       2000
# sports           2000
# business         2000
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# headlines      0
# description    0
# content        0
# url            0
# category       0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 5)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (10000, 5)

# %%
df
# Out:
#                                               headlines  \
# 0     Alia Bhatt cheers for husband Ranbir Kapoor af...
# 1     UGC removes Meghalaya’s Techno Global Universi...
# 2     Redmi 13C 5G review: Recycling the affordable ...
# 3     Shoaib Akhtar sees Shadab Khan as the next Pak...
# 4          SEBI increases accountability of MF trustees
# ...                                                 ...
# 9995  Ranbir Kapoor’s Animal gets adults only certif...
# 9996  Google year in search 2023: Kiara Advani most ...
# 9997  Luxurious Living Redefined: Mеrlin Group annou...
# 9998  Rajkumar Hirani reveals why he didn’t want to ...
# 9999  Katrina Kaif reveals how ‘green flag’ husband ...
#
#                                             description  \
# 0     The trailer of Ranbir Kapoor's upcoming film A...
# 1     The Techno Global University, Shillong Polytec...
# 2     At Rs 10,999, the phone costs dangerously clos...
# 3     The former Pakistan pacer had criticised Babar...
# 4     While refusing to extend the time, the Delhi H...
# ...                                                 ...
# 9995  Animal marks the first collaboration between R...
# 9996  Kiara Advani and Sidharth Malhotra landed in m...
# 9997  Nestled in the heart of thе vibrant Banеr neig...
# 9998  Did you know that the role of Sukhi in Dunki l...
# 9999  Katrina Kaif and Vicky Kaushal sometimes have ...
#
#                                                 content  \
# 0     Actor Alia Bhatt is highly impressed by the tr...
# 1     The Techno Global University, Shillong Polytec...
# 2     The budget smartphone market in India is heati...
# 3     While former Pakistani speedster Shoaib Akhtar...
# 4     In a setback for low-cost airline, SpiceJet, t...
# ...                                                 ...
# 9995  The Animal is coming. Ranbir Kapoor’s latest a...
# 9996  Google year in search 2023: Kiara Advani tops ...
# 9997  Following the resounding success of its luxuri...
# 9998  Amid the mixed response that his latest film, ...
# 9999  Actor couple Katrina Kaif and Vicky Kaushal ha...
#
#                                                     url       category
# 0     https://indianexpress.com/article/entertainmen...  entertainment
# 1     https://indianexpress.com/article/education/ug...      education
# 2     https://indianexpress.com/article/technology/t...     technology
# 3     https://indianexpress.com/article/sports/crick...         sports
# 4     https://indianexpress.com/article/business/avi...       business
# ...                                                 ...            ...
# 9995  https://indianexpress.com/article/entertainmen...  entertainment
# 9996  https://indianexpress.com/article/entertainmen...  entertainment
# 9997  https://indianexpress.com/article/business/spo...       business
# 9998  https://indianexpress.com/article/entertainmen...  entertainment
# 9999  https://indianexpress.com/article/entertainmen...  entertainment
#
# [10000 rows x 5 columns]

# %%
# Dropping unwanted columns for this

df = df.drop(columns= ['url'])
df_copy = df.copy()
df
# Out:
#                                               headlines  \
# 0     Alia Bhatt cheers for husband Ranbir Kapoor af...
# 1     UGC removes Meghalaya’s Techno Global Universi...
# 2     Redmi 13C 5G review: Recycling the affordable ...
# 3     Shoaib Akhtar sees Shadab Khan as the next Pak...
# 4          SEBI increases accountability of MF trustees
# ...                                                 ...
# 9995  Ranbir Kapoor’s Animal gets adults only certif...
# 9996  Google year in search 2023: Kiara Advani most ...
# 9997  Luxurious Living Redefined: Mеrlin Group annou...
# 9998  Rajkumar Hirani reveals why he didn’t want to ...
# 9999  Katrina Kaif reveals how ‘green flag’ husband ...
#
#                                             description  \
# 0     The trailer of Ranbir Kapoor's upcoming film A...
# 1     The Techno Global University, Shillong Polytec...
# 2     At Rs 10,999, the phone costs dangerously clos...
# 3     The former Pakistan pacer had criticised Babar...
# 4     While refusing to extend the time, the Delhi H...
# ...                                                 ...
# 9995  Animal marks the first collaboration between R...
# 9996  Kiara Advani and Sidharth Malhotra landed in m...
# 9997  Nestled in the heart of thе vibrant Banеr neig...
# 9998  Did you know that the role of Sukhi in Dunki l...
# 9999  Katrina Kaif and Vicky Kaushal sometimes have ...
#
#                                                 content       category
# 0     Actor Alia Bhatt is highly impressed by the tr...  entertainment
# 1     The Techno Global University, Shillong Polytec...      education
# 2     The budget smartphone market in India is heati...     technology
# 3     While former Pakistani speedster Shoaib Akhtar...         sports
# 4     In a setback for low-cost airline, SpiceJet, t...       business
# ...                                                 ...            ...
# 9995  The Animal is coming. Ranbir Kapoor’s latest a...  entertainment
# 9996  Google year in search 2023: Kiara Advani tops ...  entertainment
# 9997  Following the resounding success of its luxuri...       business
# 9998  Amid the mixed response that his latest film, ...  entertainment
# 9999  Actor couple Katrina Kaif and Vicky Kaushal ha...  entertainment
#
# [10000 rows x 4 columns]

# %% [markdown]
# ### Making Pipeline

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import re
import string

class processing(BaseEstimator,TransformerMixin) :
    def fit(self, x, y=None ) :
        return self

    def healper(self, x):
        x = re.sub(r'[^a-zA-z\s]','',x.lower())
        return ' '.join(x.split())

    def transform(self, x) :
        combined = (x['headlines'].astype(str) + ' ' +
                    x['description'].astype(str) + ' ' +
                    x['content'].astype(str))

        return combined.apply(self.healper).tolist()

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

text_pipe = Pipeline([
    ('Text',processing()),
    ('Vectorizer', TfidfVectorizer(stop_words='english'))
])

prep_pipe = ColumnTransformer([
    ('Processing', text_pipe,['headlines', 'description', 'content'])
], remainder= 'passthrough')

pipe = Pipeline([
    ('preprocessing', prep_pipe),
    ('Classifier', LogisticRegression(max_iter= 1000, class_weight= 'balanced'))
])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['enc'] = le.fit_transform(df['category'])

# %%
df['enc'].value_counts()
# Out:
# enc
# 2    2000
# 1    2000
# 4    2000
# 3    2000
# 0    2000
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df.drop(columns=['category', 'enc']), df['enc'], test_size= 0.33, random_state= 42)

# %%
x_train
# Out:
#                                               headlines  \
# 8371  I feel he should be given one more chance: Sun...
# 5027  Current account deficit in April-June narrows ...
# 9234  Popular online chat website Omegle shuts down ...
# 3944  What ails India’s women’s hockey team: No big ...
# 6862  Markets decline in early trade on weak global ...
# ...                                                 ...
# 5734  ‘Why humanities courses are integral – not sup...
# 5191  When Karan Johar surprised Shah Rukh Khan by c...
# 5390  India among eight direct qualifiers for Women’...
# 860   Consumerware player Cello World sets IPO price...
# 7270  ‘Shaheen bahot accha hai, Bumrah toh uske paas...
#
#                                             description  \
# 8371  IND vs AUS: Another former India player Madan ...
# 5027  The widening of CAD on a quarter-on-quarter ba...
# 9234  Omegle, the popular online chat website that l...
# 3944  The triumph at the Asian Champions Trophy, a p...
# 6862  Rallying for the third day, the Sensex climbed...
# ...                                                 ...
# 5734  "Whereas engineers are taught to think in term...
# 5191  Recently, Karan Johar revisited shooting one o...
# 5390  The top-three teams from each group of the rec...
# 860   The issue will open for public subscription on...
# 7270  Both Afridi and Bumrah have been out of action...
#
#                                                 content
# 8371  IND vs AUS: India legend Sunil Gavaskar has ba...
# 5027  India’s current account deficit (CAD) narrowed...
# 9234  Omegle, a popular website that allowed people ...
# 3944  “I don’t know.”\nWith these words, India coach...
# 6862  Equity benchmark indices declined in early tra...
# ...                                                 ...
# 5734  (A Lesson from IIT is a weekly column by an II...
# 5191  To this day, Karan Johar’s directorial debut f...
# 5390  India, by virtue of finishing inside the top-t...
# 860   Household products and stationery manufacturer...
# 7270  Shaheen Shah Afridi and Jasprit Bumrah share 5...
#
# [6700 rows x 3 columns]

# %%
pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Processing',
#                                                   Pipeline(steps=[('Text',
#                                                                    processing()),
#                                                                   ('Vectorizer',
#                                                                    TfidfVectorizer(stop_words='english'))]),
#                                                   ['headlines', 'description',
#                                                    'content'])])),
#                 ('Classifier',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
pred = pipe.predict(x_test)

# %%
y_test
# Out:
# 6252    2
# 4684    3
# 1731    1
# 4742    1
# 4521    2
#        ..
# 1744    0
# 9754    4
# 6094    4
# 8781    1
# 9401    3
# Name: enc, Length: 3300, dtype: int64

# %%
pred
# Out:
# array([2, 3, 1, ..., 4, 1, 3])

# %%
from sklearn.metrics import accuracy_score, classification_report

acc = accuracy_score(y_true= y_test, y_pred= pred)

acc
# Out:
# 0.9812121212121212

# %%
pipe.score(x_train, y_train)
# Out:
# 0.9943283582089553

# %%
pipe.score(x_test, y_test)
# Out:
# 0.9812121212121212

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       656
#            1       0.99      0.98      0.99       669
#            2       1.00      0.99      0.99       669
#            3       0.99      0.99      0.99       665
#            4       0.96      0.97      0.96       641
#
#     accuracy                           0.98      3300
#    macro avg       0.98      0.98      0.98      3300
# weighted avg       0.98      0.98      0.98      3300
